# %%
from fastai import *
from fastai.vision import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import IPython
# IPython.display.Audio("/content/drive/My Drive/GunShot/9_mm_gunshot-mike-koenig-123.wav")

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import specgram
import librosa
import librosa.display
import numpy as np
def create_fold_spectrograms():
    spectrogram_path = Path('/content/drive/My Drive/GunShot/test/music')  
    audio_path = Path('/content/drive/My Drive/GunShot/test/music/')  
    for audio_file in list(Path(audio_path).glob('*.mp3')):
        samples, sample_rate = librosa.load(audio_file)
        fig = plt.figure(figsize=[0.72,0.72])
        ax = fig.add_subplot(111)
        ax.axes.get_xaxis().set_visible(False)
        ax.axes.get_yaxis().set_visible(False)
        ax.set_frame_on(False)
        filename  = spectrogram_path/Path(audio_file).name.replace('.mp3','.png')
        S = librosa.feature.melspectrogram(y=samples, sr=sample_rate)
        librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
        plt.savefig(filename, dpi=400, bbox_inches='tight',pad_inches=0)
        plt.close('all')

# %%
create_fold_spectrograms()

# %%
# folder = 'nonGun'
# file = 'random.csv'

# %%
path = Path('/content/drive/My Drive/GunShot/dataset')
# dest = path/folder
# dest.mkdir(parents=True, exist_ok=True)

# %%
# download_images(path/file, dest, max_pics=500)

# %%
# verify_images(path/folder, delete=True, max_size=500)

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['gun', 'non gun']

# %%
data.show_batch(rows=5, figsize=(5,6))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['gun'], 1, 164, 40)

# %%
import os

# %%
path, dirs, files = next(os.walk('/content/drive/My Drive/GunShot/dataset/gun/'))
file_count = len(files)

# %%
print(file_count)
# Out:
# 204

# %%
from fastai.metrics import error_rate, accuracy

# %%
learn = cnn_learner(data, models.resnet50, metrics=accuracy)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.238810</td>
#       <td>0.069328</td>
#       <td>0.987727</td>
#       <td>04:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.190302</td>
#       <td>0.055585</td>
#       <td>0.993455</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.098319</td>
#       <td>0.027109</td>
#       <td>0.997545</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.049098</td>
#       <td>0.0159839</td>
#       <td>0.999845</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot(suggestion= True)
# Out:
# Min numerical gradient: 1.20E-05
# Min loss divided by 10: 6.31E-08

# %%
learn.fit_one_cycle(2, max_lr = slice(1e-5,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.056711</td>
#       <td>0.050806</td>
#       <td>0.999545</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.034622</td>
#       <td>0.020987</td>
#       <td>0.999273</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
# img = open_image('/content/drive/My Drive/GunShot/dataset/gun/50_sniper_shot-Liam-2028603980.png')
# img
img = open_image('/content/drive/My Drive/GunShot/test/Gun-M16A4-Burst.png')
img
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-14077c5613d8> in <module>()
# ----> 1 img = open_image('/content/drive/My Drive/GunShot/test/Gun-M16A4-Burst.png')
#       2 img
#
# /usr/local/lib/python3.6/dist-packages/fastai/vision/image.py in open_image(fn, div, convert_mode, cls, after_open)
#     396     with warnings.catch_warnings():
#     397         warnings.simplefilter("ignore", UserWarning) # EXIF warning from TiffPlugin
# --> 398         x = PIL.Image.open(fn).convert(convert_mode)
#     399     if after_open: x = after_open(x)
#     400     x = pil2tensor(x,np.float32)
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2528
#    2529     if filename:
# -> 2530         fp = builtins.open(filename, "rb")
#    2531         exclusive_fp = True
#    2532
#
# ...

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category gun
